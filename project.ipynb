# %%
{
  "name": "infrared-city",
  "image": "mcr.microsoft.com/devcontainers/python:3.11",
  "features": {},
  "postCreateCommand": "pip install -r requirements.txt || pip install notebook",
  "customizations": {
    "vscode": {
      "extensions": [
        "ms-python.python",
        "ms-toolsai.jupyter"
      ]
    }
  }
}
# Out:
# {'name': 'infrared-city',
#  'image': 'mcr.microsoft.com/devcontainers/python:3.11',
#  'features': {},
#  'postCreateCommand': 'pip install -r requirements.txt || pip install notebook',
#  'customizations': {'vscode': {'extensions': ['ms-python.python',
#     'ms-toolsai.jupyter']}}}

# %%
print ("hello")
# Out:
# hello

# %%
#test
